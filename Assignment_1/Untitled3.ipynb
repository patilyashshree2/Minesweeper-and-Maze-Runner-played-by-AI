# %%
import math
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
import random
def genMaze(dim,p):
    maze = []
    for x in range(dim):
        row = []
        for y in range(dim):
            if random.random() > p:
                row.append(0)
            else :
                row.append(1)
        maze.append(row)
    maze[0][0] = 0
    maze[dim-1][dim-1] = 0
    return maze

# %%
maze = genMaze(20,0.20)

# %%
maze

# %%
def draw(maze):
  blocked = "⬛"
  free = "⬜"
  for row in maze:
    tiles = ""
    for tile in row:
      tiles += blocked if tile==1 else free
    print(tiles)

# %%
draw(maze)

# %%
def A_STAR_M(data,dim):
    fringe = [[0,0,0,0,0]]
    visited = []
    current=[]
    path = []
    print(fringe)
    g = 0
    while len(fringe) != 0 :
        cost=[]
        for z in fringe:
            cost.append(z[4])
        print(cost)
        min_cost = cost.index(min(cost))
        current = fringe[min_cost]
        visited.append(current[0:4])
        fringe.remove(current)
        i = current[0]
        j = current[1]
        
        if i == (dim-1) and j == (dim-1) :
            print('goal state reached')
            print(visited)
            
            while (i!=0 or j!=0):
                for ele in visited :
                    if(ele[0]==i and ele[1]==j) :
                        path.append([i,j])
                        i = ele[2]
                        j = ele[3]
            path.append([0,0])
            print('SOLUTION PATH')
            print(path)
            
            return path
            
        else :
            
            if i==0 and j==0 : #expansion of start state
                
                if data[i+1][j] != 1 and [i+1,j] :
                    state = False
                    for z in visited:
                        if ([i+1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i+1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i+1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i+1,j,i,j,f])
                            print(fringe)
                            
                if data[i][j+1] != 1 :  #expand the right cell
                    state = False
                    for z in visited:
                        if ([i,j+1] == z[:2]):
                            state = True
                            
                    if(not state):  
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j+1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j+1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j+1,i,j,f])
                            print(fringe)
                        
            if i>=1 and j>=1 and i<(dim-1) and j<(dim-1) : #expansion for inner cells (leaving outmost cells)
                
                if data[i][j-1] != 1 :
                    state = False
                    for z in visited:
                        if ([i,j-1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j-1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j-1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j-1,i,j,f])
                            print(fringe)
                    
                if data[i-1][j] != 1 :
                    state = False
                    for z in visited:
                        if ([i-1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i-1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i-1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i-1,j,i,j,f])
                            print(fringe)
                        
                        
                if data[i+1][j] != 1:
                    state = False
                    for z in visited:
                        if ([i+1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i+1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i+1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i+1,j,i,j,f])
                            print(fringe)
                        
                        
                if data[i][j+1] != 1 :
                    state = False
                    for z in visited:
                        if ([i,j+1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j+1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j+1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j+1,i,j,f])
                            print(fringe)
                        
                        
            if i==0 and j <(dim-1) and j >= 1 : #expansion of cells in first row leaving right most cell and starting state
                if data[i][j-1] != 1 :
                    state = False
                    for z in visited:
                        if ([i,j-1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j-1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j-1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j-1,i,j,f])
                            print(fringe)
                        
                        
                if data[i+1][j] != 1 :
                    state = False
                    for z in visited:
                        if ([i+1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i+1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i+1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i+1,j,i,j,f])
                            print(fringe)
                        
                        
                if data[i][j+1] != 1 :
                    state = False
                    for z in visited:
                        if ([i,j+1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j+1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j+1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j+1,i,j,f])
                            print(fringe)
                        
                        
            if i==0 and j==(dim-1) : #expansion of right topmost cell
                if data[i][j-1] != 1 :
                    state = False
                    for z in visited:
                        if ([i,j-1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j-1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j-1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j-1,i,j,f])
                            print(fringe)
                        
                        
                if data[i+1][j] != 1 :
                    state = False
                    for z in visited:
                        if ([i+1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i+1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i+1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i+1,j,i,j,f])
                            print(fringe)
                        
                        
            if i<(dim-1) and i>=1 and j==0 : #expansion of cells in first column leaving bottom most cell and start state
                if data[i-1][j] != 1 :
                    state = False
                    for z in visited:
                        if ([i-1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i-1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i-1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i-1,j,i,j,f])
                            print(fringe)
                        
                        
                if data[i+1][j] != 1 :
                    state = False
                    for z in visited:
                        if ([i+1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i+1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i+1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i+1,j,i,j,f])
                            print(fringe)
                        
                        
                if data[i][j+1] != 1 :
                    state = False
                    for z in visited:
                        if ([i,j+1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j+1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j+1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j+1,i,j,f])
                            print(fringe)
                        
                        
            if i==(dim-1) and j!=0 and j<(dim-1) : #expansion of bottom most row except goal state and leftmost state
                if data[i][j-1] != 1 :
                    state = False
                    for z in visited:
                        if ([i,j-1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j-1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j-1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j-1,i,j,f])
                            print(fringe)
                        
                        
                if data[i-1][j] !=1 :
                    state = False
                    for z in visited:
                        if ([i-1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i-1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i-1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i-1,j,i,j,f])
                            print(fringe)
                        
                        
                if data[i][j+1] != 1 :
                    state = False
                    for z in visited:
                        if ([i,j+1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j+1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j+1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j+1,i,j,f])
                            print(fringe)
                        
                        
            if j==(dim-1) and i!= 0 and i<(dim-1) : #expansion of right most column leaving top most cell and goal state
                if data[i][j-1] !=1 :
                    state = False
                    for z in visited:
                        if ([i,j-1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j-1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j-1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j-1,i,j,f])
                            print(fringe)
                        
                        
                if data[i-1][j] !=1 :
                    state = False
                    for z in visited:
                        if ([i-1,j] == x[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i-1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i-1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i-1,j,i,j,f])
                            print(fringe)
                        
                        
                if data[i+1][j] != 1 :
                    state = False
                    for z in visited:
                        if ([i+1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i+1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i+1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i+1,j,i,j,f])
                            print(fringe)
                        
                        
            if i==(dim-1) and j==0 : #expansion of left most bottom cell
                if data[i-1][j] != 1  :
                    state = False
                    for z in visited:
                        if ([i-1,j] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i-1,j] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i-1,j] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i-1,j,i,j,f])
                            print(fringe)
                        
                        
                if data[i][j+1] != 1 :
                    state = False
                    for z in visited:
                        if ([i,j+1] == z[:2]):
                            state = True
                            
                    if(not state):
                        g = g+1
                        f = g+18-i-j
                        flag = False
                        for x in fringe:
                            if ([i,j+1] == x[:2] and f > x[4]): 
                                flag = True 
                            
                            if ([i,j+1] == x[:2] and f < x[4]): 
                            
                                fringe.remove(x)
                                break
                        if(not flag):
                            fringe.append([i,j+1,i,j,f])
                            print(fringe)
                        
                                
    if len(fringe) == 0 :
        print("solution not found")
